# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDVJSINGH/Multiclass-Disease-Detection-Model/blob/main/multiclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Converting Image type from .jpg to .jpeg for the model to work up on**

# %%
# import os

# # Set the directory containing the images
# directory = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/eczema/"

# iterator = 0

# # Iterate through all files in the directory
# for filename in os.listdir(directory):
#     if filename.endswith(".jpg",".png",):
#         # Construct the old and new filenames
#         old_file = os.path.join(directory, filename)
#         new_file = os.path.join(directory, filename.replace(".jpg", ".jpeg"))

#         # Rename the file
#         os.rename(old_file, new_file)
#         iterator = iterator + 1

# print(f"File extensions successfully converted from .jpg to .jpeg, image count {iterator}")

# %% [markdown]
# # Converts all image to .jpeg

# %%
# from PIL import Image
# import os

# # Set the directory containing the images
# directory = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/psoriasis/"

# iterator:int = 0
# # Iterate through all files in the directory
# for filename in os.listdir(directory):
#     if any(filename.lower().endswith(ext) for ext in [".jpg", ".png", ".bmp", ".gif"]):
#         # Open the image
#         img = Image.open(os.path.join(directory, filename))

#         # Convert palette (P) mode images to RGB
#         if img.mode == 'P':
#             img = img.convert('RGB')

#         # Convert RGBA images to RGB
#         elif img.mode == 'RGBA':
#             img = img.convert('RGB')

#         # Construct the new filename with the .jpeg extension
#         new_file = os.path.join(directory, os.path.splitext(filename)[0] + ".JPEG")

#         # Save the image in JPEG format
#         img.save(new_file, "JPEG")

#         # Delete the old image file
#         os.remove(os.path.join(directory, filename))
#         iterator = iterator + 1

# print(f"Images successfully converted to .jpeg format. total count {iterator}")

# %% [markdown]
# # Types of File Format Checker

# %%
# import os

# def filetype_checker(directory:str):
#   # Iterate through all files in the directory
#   format_counts = {}
#   for filename in os.listdir(directory):
#     file_format = filename.split('.')[-1].lower()  # Extract the file format
#     if file_format not in format_counts:
#         format_counts[file_format] = 1
#     else:
#         format_counts[file_format] += 1
#   return format_counts

# def printing(format_counts:dict, type:str):
# # Print the file formats along with their counts
#   print(f"{type}")
#   for file_format, count in format_counts.items():
#       print(f"File format: {file_format}, Count: {count}")


# # Malanoma
# dir_malanoma_test = "/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/malanoma/"
# test_malanoma = filetype_checker(dir_malanoma_test)
# printing(test_malanoma, "Test-Malanoma")

# print(" ")

# dir_malanoma_train = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/malanoma/"
# train_malanoma = filetype_checker(dir_malanoma_train)
# printing(train_malanoma, "Train-Malanoma")

# print(" ")

# # Eczema
# dir_eczema_test = "/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/eczema/"
# test_eczema = filetype_checker(dir_eczema_test)
# printing(test_eczema, "Test-eczema")

# print(" ")

# dir_eczema_train = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/eczema/"
# train_eczema = filetype_checker(dir_eczema_train)
# printing(train_eczema, "Train-eczema")

# print(" ")

# # Psoriasis
# dir_psoriasis_test = "/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/psoriasis/"
# test_psoriasis = filetype_checker(dir_psoriasis_test)
# printing(test_psoriasis, "Test-psoriasis")

# print(" ")

# dir_psoriasis_train = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/psoriasis/"
# train_psoriasis = filetype_checker(dir_psoriasis_train)
# printing(train_psoriasis, "Train-psoriasis")

# print(" ")

# # Healthy
# dir_healthy_test = "/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/healthy/"
# test_healthy = filetype_checker(dir_healthy_test)
# printing(test_healthy, "Test-healthy")

# print(" ")

# dir_healthy_train = "/content/drive/MyDrive/Colab Notebooks/model_dataset/training/healthy/"
# train_healthy = filetype_checker(dir_healthy_train)
# printing(train_healthy, "Train-healthy")

# %%
# !pip install tensorflow opencv-python matplotlib

# %%
import tensorflow as tf
import os

# %%
import cv2
import imghdr
from matplotlib import pyplot as plt

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/model_dataset/testing'
# data_dir = '/content/drive/MyDrive/Colab Notebooks/model_dataset/training'

# %%
types = list(os.listdir(data_dir))
types
# Out:
# ['psoriasis', 'malanoma', 'healthy', 'eczema']

# %%
dict_mapping = {}

for i in range(len(types)):
  dict_mapping[types[i]] = i

print(dict_mapping)
# Out:
# {'psoriasis': 0, 'malanoma': 1, 'healthy': 2, 'eczema': 3}

# %%
image_exts = ['jpeg', 'bmp', 'png', 'gif']

# %%
img = cv2.imread(os.path.join('/content/drive/MyDrive/Colab Notebooks/model_dataset/training/eczema/0_0.jpeg'))
img.shape
# Out:
# (222, 294, 3)

# %%
# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# for image_class in os.listdir(data_dir):
#     for image in os.listdir(os.path.join(data_dir, image_class)):
#         image_path = os.path.join(data_dir, image_class, image)
#         try:
#             img = cv2.imread(image_path)
#             tip = imghdr.what(image_path)
#             if tip not in image_exts:
#                 print('Image not in ext list {}'.format(image_path))
#                 # os.remove(image_path)
#         except Exception as e:
#             print('Issue with image {}'.format(image_path))
#             # os.remove(image_path)

# %%
# tf.data.Dataset??

# %%
import numpy as np

# %%
# data = tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/Colab Notebooks/model_dataset/training/')

# %% [markdown]
# # **Training on Testing Data**

# %%
data = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False
)
# Out:
# Found 1033 files belonging to 4 classes.
# Using 827 files for training.

# %%
# tf.keras.utils.image_dataset_from_directory??

# %%
data_iterator = data.as_numpy_iterator()
data_iterator

# %%
# get another batch
batch = data_iterator.next()
len(batch)
# Out:
# 2

# %%
# psoriasis : 0 , malanoma : 1, healthy: 2, eczema: 3
fig, ax = plt.subplots(ncols=8, figsize=(20,20))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# batch[0].shape

# %%
# scaled = batch[0]/255

# %%
# scaled.max()

# %%
# data = data.map(lambda x, y: (x / 255, tf.one_hot(y, 4)))
# tf.image??

# %%
from tensorflow.python.ops.gen_image_ops import decode_jpeg

# %%
def preprocess_data(image, label):
    image = tf.image.resize(image, (256, 256))  # Resize the images to a uniform size
    image = tf.cast(image, tf.float32) / 255.0  # Normalize the pixel values to [0, 1]
    label = tf.one_hot(label, depth=4)  # One-hot encode the labels
    return image, label

# Assuming 'data' is your dataset
data = data.map(preprocess_data)

# %%
# data.as_numpy_iterator().next()[0].min()
# data.as_numpy_iterator().next()[0].max()

# %%
len(data)
# Out:
# 26

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
# test_size

# %%
train = data.take(train_size) # How much data is to take
val = data.skip(train_size).take(val_size) # Skip the batch that is in train
test = data.skip(train_size+val_size).take(test_size) # Take the rest data

# %%
print(f"val: {val}")
print(f"train: {train}")
print(f"test: {test}")
# Out:
# val: <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>
# train: <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>
# test: <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %% [markdown]
# # **VGG16** **Model**

# %% [markdown]
# Working but takes too much time

# %%
# from tensorflow.keras.applications import VGG16
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Dense, Flatten, Dropout

# # Load the pre-trained VGG16 model
# base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# # Create your custom model by adding layers on top of the VGG16 base model
# x = base_model.output
# x = Flatten()(x)
# x = Dense(256, activation='relu')(x) # Number of Neurons
# x = Dropout(0.5)(x)  # Optional dropout layer for regularization
# predictions = Dense(4, activation='softmax')(x)

# # Combine the base VGG16 model with your custom layers
# model = Model(inputs=base_model.input, outputs=predictions)

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Display the model summary
# model.summary()

# # Set up TensorBoard for monitoring the training process
# logdir = '/content/drive/MyDrive/Colab Notebooks/logs'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

## Train the model
# hist = model.fit(train, epochs=5, validation_data=val, callbacks=[tensorboard_callback])

# %% [markdown]
# # **MobileNetV2**

# %% [markdown]
# Less Accuracy

# %%
# from tensorflow.keras.applications import MobileNetV2
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# # Load the pre-trained MobileNetV2 model
# base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# # Add custom layers on top of the MobileNetV2 base model
# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(256, activation='relu')(x) # Number of Neurons
# predictions = Dense(4, activation='softmax')(x)

# # Combine the base MobileNetV2 model with your custom layers
# model = Model(inputs=base_model.input, outputs=predictions)

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Display the model summary
# model.summary()

# # Set up TensorBoard for monitoring the training process
# logdir = '/content/drive/MyDrive/Colab Notebooks/logs'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# # Train the model
# hist = model.fit(train, epochs=5, validation_data=val, callbacks=[tensorboard_callback])

# %% [markdown]
# # **Inception V3 Model**

# %% [markdown]
# Less Accuracy

# %%
# import tensorflow as tf
# from tensorflow.keras.applications import InceptionV3
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# # Load the pre-trained InceptionV3 model
# base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# # Add custom layers on top of the InceptionV3 base model
# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(256, activation='relu')(x) # Number of Neurons
# predictions = Dense(4, activation='softmax')(x)

# # Combine the base InceptionV3 model with your custom layers
# model = Model(inputs=base_model.input, outputs=predictions)

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Display the model summary
# model.summary()

# # Set up TensorBoard for monitoring the training process
# logdir = '/content/drive/MyDrive/Colab Notebooks/logs'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# # Train the model
# hist = model.fit(train, epochs=5, validation_data=val, callbacks=[tensorboard_callback])

# %% [markdown]
# # **DenseNet121 Model**

# %% [markdown]
# Time Taking
# accuracy increases iteratively

# %%
# import tensorflow as tf
# from tensorflow.keras.applications import DenseNet121
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# # Load the pre-trained DenseNet121 model
# base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# # Add custom layers on top of the DenseNet121 base model
# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(256, activation='relu')(x) # Number of Neurons
# predictions = Dense(4, activation='softmax')(x)

# # Combine the base DenseNet121 model with your custom layers
# model = Model(inputs=base_model.input, outputs=predictions)

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Display the model summary
# model.summary()

# # Set up TensorBoard for monitoring the training process
# logdir = '/content/drive/MyDrive/Colab Notebooks/logs'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# # Train the model
# hist = model.fit(train, epochs=5, validation_data=val, callbacks=[tensorboard_callback])

# %% [markdown]
# # **Sequential Model**

# %% [markdown]
# Much **Accurate!**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# Define the Sequential model
model = Sequential()

# Add layers to the Sequential model
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu')) # Number of Neurons
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))  # Four classes for classification

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()

# Set up TensorBoard for monitoring the training process
logdir = '/content/drive/MyDrive/Colab Notebooks/logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# Train the model
hist = model.fit(train, epochs=50, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 115200)            0
#
#  dense_2 (Dense)             (None, 256)               29491456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# ...
# Total params: 29585732 (112.86 MB)
# Trainable params: 29585732 (112.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ...

# %% [markdown]
# # **Visualizing**

# %%
hist.history
# Out:
# {'loss': [2.519057273864746,
#   1.147747278213501,
#   0.9794755578041077,
#   0.8805921673774719,
#   0.8170586228370667,
#   0.6873791813850403,
#   0.6297476291656494,
#   0.6470105648040771,
#   0.5085300803184509,
#   0.43375492095947266,
#   0.42996904253959656,
#   0.45939937233924866,
#   0.43686342239379883,
#   0.3329465389251709,
#   0.2756686806678772,
#   0.2426707148551941,
#   0.187106192111969,
#   0.18351323902606964,
#   0.18046241998672485,
#   0.16107162833213806,
#   0.13379640877246857,
#   0.16014504432678223,
#   0.16043730080127716,
#   0.20357806980609894,
#   0.18835537135601044,
#   0.15865379571914673,
#   0.09687767177820206,
#   0.0881936252117157,
#   0.06816757470369339,
#   0.15979455411434174,
#   0.13817471265792847,
#   0.07753418385982513,
#   0.04433903470635414,
#   0.04989110305905342,
#   0.061055224388837814,
#   0.08707136660814285,
#   0.06111380085349083,
#   0.052892062813043594,
#   0.08270503580570221,
#   0.07466170191764832,
# ...

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# Evaluation"

# %%
from tensorflow.keras.metrics import Precision, Recall, CategoricalAccuracy

# %%
#
pre = Precision()
re = Recall()
acc = CategoricalAccuracy()

# %%
# len(test)

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# ...
# 1/1 [==============================] - 1s 685ms/step

# %%
print(f"Precision: {pre.result()}, Recall: {re.result()}, Accuracy: {acc.result()}")
# Out:
# Precision: 1.0, Recall: 1.0, Accuracy: 1.0

# %% [markdown]
# # **Save this model**

# %%
from tensorflow.keras.models import load_model
model.save('/content/drive/MyDrive/Colab Notebooks/models/multiclass-seq.keras')

# %% [markdown]
# # **Testing**

# %% [markdown]
# ## Healthy

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/healthy/6.6.jpeg')
img.shape
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## **Eczema**

# %%
# img = cv2.imread(os.path.join('/content/drive/MyDrive/Colab Notebooks/model_dataset/testing/eczema/2_1.jpeg'))
# img.shape
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# plt.show()

# %%
# Resize before putting it into the model

resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, axis=0))
# np.expand_dims??
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
yhat
# Out:
# array([[3.2066113e-05, 6.0276821e-04, 9.4710410e-01, 5.2261025e-02]],
#       dtype=float32)

# %%
# Save this model

from tensorflow.keras.models import load_model

new_model = load_model('/content/drive/MyDrive/Colab Notebooks/models/multiclass-seq.keras')
prediction = new_model.predict(np.expand_dims(resize/255, 0))

print(f"prediction matrix : {prediction}")
# Out:
# 1/1 [==============================] - 0s 93ms/step
# prediction matrix : [[3.2066113e-05 6.0276821e-04 9.4710410e-01 5.2261025e-02]]

# %% [markdown]
# # **Prediction**

# %%
# import numpy as np

class_names = ['Psoriasis', 'Malanoma', 'Healthy', 'Eczema']  # Define the class names

# Get the index of the class with the highest probability
predicted_class_index = np.argmax(prediction)

# Find the class name using the predicted class index
predicted_class = class_names[predicted_class_index]

print(f"The predicted class is: {predicted_class}")
# Out:
# The predicted class is: Healthy
